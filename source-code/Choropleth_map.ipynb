# %% [markdown]
# ### Import the Necessary Libraries

# %%
import folium
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

pd.options.display.max_columns = 999
# Out:
# /Users/mahsumkocabey/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/mahsumkocabey/opt/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# <ipython-input-1-03fae1edc20b>:4: DeprecationWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas still uses PyGEOS by default. However, starting with version 0.14, the default will switch to Shapely. To force to use Shapely 2.0 now, you can either uninstall PyGEOS or set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In the next release, GeoPandas will switch to using Shapely by default, even if PyGEOS is installed. If you only have PyGEOS installed to get speed-ups, this switch should be smooth. However, if you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %% [markdown]
# ### Read the Data

# %%
# Load the GeoJSON file
boroughs_gdf = gpd.read_file('../data/LAS/london_sport.json')
boroughs_gdf['name'] = boroughs_gdf['name'].str.title()

# Load the LAS Locations
las_data = pd.read_csv('../data/LAS/LAS Locations.csv')
# Load the LFB Locations
lfb_data = pd.read_csv('../data/LFB/LFB Locations.csv')

# %% [markdown]
# ### Convert Them into Geographic Data

# %%
# Convert the DataFrame into a GeoDataFrame
geometry_lfb = [Point(xy) for xy in zip(lfb_data.Longitude, lfb_data.Latitude)]
lfb_gdf = gpd.GeoDataFrame(lfb_data, geometry=geometry_lfb)

# Set the original CRS to WGS 84
lfb_gdf.set_crs(epsg=4326, inplace=True)

# Convert the CRS to UK National Grid
lfb_gdf = lfb_gdf.to_crs(epsg=27700)

# %%
# Convert the DataFrame into a GeoDataFrame
geometry = [Point(xy) for xy in zip(las_data.Longitude, las_data.Latitude)]
las_gdf = gpd.GeoDataFrame(las_data, geometry=geometry)

# Set the original CRS to WGS 84
las_gdf.set_crs(epsg=4326, inplace=True)

# Convert the CRS to UK National Grid
las_gdf = las_gdf.to_crs(epsg=27700)

# %% [markdown]
# ### Create a Map with Station Locations Only

# %%
# Create a map centered around London
lfb_m = folium.Map(location=[51.5074, -0.1278], zoom_start=10)

# Add a marker for each location in the DataFrame
for index, row in lfb_data.iterrows():
    folium.Marker(location=[row['Latitude'], row['Longitude']], 
                  popup=f"{row['Station/code']}, {row['Address']}"
                 ).add_to(lfb_m)

# Add the GeoJSON to the folium map
folium.GeoJson(
    boroughs_gdf,
    name='geojson',
    style_function=lambda feature: {
        'fillColor': 'yellow',  # you can also use different colors, it's up to you
        'color': 'red',
        'weight': 1,
        'dashArray': '5, 5',
        'fillOpacity': 0.3,
    }
).add_to(lfb_m)

folium.TileLayer('cartodbpositron').add_to(lfb_m)

lfb_m.save('lfb_map.html')

# Show the map
lfb_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab9910c2dca276ffcea6ffe7b5a15320 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab9910c2dca276ffcea6ffe7b5a15320&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab9910c2dca276ffcea6ffe7b5a15320 = L.map(
#                 &quot;map_ab9910c2dca276ffcea6ffe7b5a15320&quot;,
#                 {
#                     center: [51.5074, -0.1278],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b93c837a2d001e6d6a49031849777b54 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab9910c2dca276ffcea6ffe7b5a15320);
#
#
#             var marker_4efbcb8ffa91086e2bb391be7188cedb = L.marker(
#                 [51.5294843, 0.0902007],
#                 {}
#             ).addTo(map_ab9910c2dca276ffcea6ffe7b5a15320);
#
#
#         var popup_1fcc02815cf7407cdabd25551ffb041f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ab87e8284f9f88c63442bc1e6a75aaa = $(`&lt;div id=&quot;html_2ab87e8284f9f88c63442bc1e6a75aaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barking, Alfred&#x27;s Way, IG11 0BB&lt;/div&gt;`)[0];
#                 popup_1fcc02815cf7407cdabd25551ffb041f.setContent(html_2ab87e8284f9f88c63442bc1e6a75aaa);
#
#
#
#         marker_4efbcb8ffa91086e2bb391be7188cedb.bindPopup(popup_1fcc02815cf7407cdabd25551ffb041f)
#         ;
#
#
#
#
#             var marker_0accc107f8aa9c479a260b86b31ede27 = L.marker(
#                 [51.5593514, 0.1569352],
#                 {}
#             ).addTo(map_ab9910c2dca276ffcea6ffe7b5a15320);
#
#
#         var popup_96ddf071a32403a6fd649ba36eeb192b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ab3b4158041a2ffbeafd5d565dd7d76 = $(`&lt;div id=&quot;html_4ab3b4158041a2ffbeafd5d565dd7d76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dagenham, 70 Rainham Road North, Dagenham, RM10 7ES&lt;/div&gt;`)[0];
#                 popup_96ddf071a32403a6fd649ba36eeb192b.setContent(html_4ab3b4158041a2ffbeafd5d565dd7d76);
#
#
#
#         marker_0accc107f8aa9c479a260b86b31ede27.bindPopup(popup_96ddf071a32403a6fd649ba36eeb192b)
#         ;
#
#
#
#
#             var marker_b9320896b3a6a64b7eb8f9822236e22c = L.marker(
#                 [51.5100529, -0.0902268],
#                 {}
#             ).addTo(map_ab9910c2dca276ffcea6ffe7b5a15320);
#
#
#         var popup_ad715537981d26c248f45284ea9b08b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_967703a795ccc08d3b47689c1f905685 = $(`&lt;div id=&quot;html_967703a795ccc08d3b47689c1f905685&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dowgate, 94-95 Upper Thames Street, EC4R 3UE&lt;/div&gt;`)[0];
#                 popup_ad715537981d26c248f45284ea9b08b9.setContent(html_967703a795ccc08d3b47689c1f905685);
#
#
#
#         marker_b9320896b3a6a64b7eb8f9822236e22c.bindPopup(popup_ad715537981d26c248f45284ea9b08b9)
#         ;
#
#
#
#
#             var marker_e89ef2833135615780c9285760656529 = L.marker(
#                 [51.5264428, -0.0855632],
#                 {}
#             ).addTo(map_ab9910c2dca276ffcea6ffe7b5a15320);
#
#
#         var popup_62f21b46ec6c7bbc3e75852a7af60857 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_73d32300bcc496eb8e7771260fc33e36 = $(`&lt;div id=&quot;html_73d32300bcc496eb8e7771260fc33e36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shoreditch, 235 Old Street, EC1V 9EY&lt;/div&gt;`)[0];
#                 popup_62f21b46ec6c7bbc3e75852a7af60857.setContent(html_73d32300bcc496eb8e7771260fc33e36);
#
#
#
#         marker_e89ef2833135615780c9285760656529.bindPopup(popup_62f21b46ec6c7bbc3e75852a7af60857)
#         ;
#
#
#
#
#             var marker_bfdb517ec1a841e7f628dceb3c115504 = L.marker(
#                 [51.5624308, -0.0769413],
#                 {}
#             ).addTo(map_ab9910c2dca276ffcea6ffe7b5a15320);
#
#
#         var popup_70ab10edabf2d350825fce7d03bd7e30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83f1486dae2133e1cc988e4726f0cc19 = $(`&lt;div id=&quot;html_83f1486dae2133e1cc988e4726f0cc19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stoke Newington, 64 Stoke Newington Church Street, N16 0AR&lt;/div&gt;`)[0];
#                 popup_70ab10edabf2d350825fce7d03bd7e30.setContent(html_83f1486dae2133e1cc988e4726f0cc19);
#
#
#
#         marker_bfdb517ec1a841e7f628dceb3c115504.bindPopup(popup_70ab10edabf2d350825fce7d

# %%
# Create a map centered around London
m = folium.Map(location=[51.5074, -0.1278], zoom_start=10)

# Add a marker for each location in the DataFrame
for index, row in las_data.iterrows():
    folium.Marker(location=[row['Latitude'], row['Longitude']], 
                  popup=f"{row['Station/code']}, {row['Address']}"
                 ).add_to(m)

# Add the GeoJSON to the folium map
folium.GeoJson(
    boroughs_gdf,
    name='geojson',
    style_function=lambda feature: {
        'fillColor': 'yellow',  # you can also use different colors, it's up to you
        'color': 'red',
        'weight': 1,
        'dashArray': '5, 5',
        'fillOpacity': 0.3,
    }
).add_to(m)

folium.TileLayer('cartodbpositron').add_to(m)

m.save('map.html')

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09ebecf1246a2f78653d8cee0d248d69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09ebecf1246a2f78653d8cee0d248d69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09ebecf1246a2f78653d8cee0d248d69 = L.map(
#                 &quot;map_09ebecf1246a2f78653d8cee0d248d69&quot;,
#                 {
#                     center: [51.5074, -0.1278],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43c59f44d53260d8123850ed8fdf5dbb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_09ebecf1246a2f78653d8cee0d248d69);
#
#
#             var marker_c37d188279088874fdf13ab866875cb6 = L.marker(
#                 [51.4608009, 0.153816],
#                 {}
#             ).addTo(map_09ebecf1246a2f78653d8cee0d248d69);
#
#
#         var popup_6ae797a01a4db35771070e8d16ee6885 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d92289ee95dac32b158c50ca7fccd8a = $(`&lt;div id=&quot;html_3d92289ee95dac32b158c50ca7fccd8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barnehurst (L1), 164 Erith Road, Bexleyheath, Kent, DA7 6BZ&lt;/div&gt;`)[0];
#                 popup_6ae797a01a4db35771070e8d16ee6885.setContent(html_3d92289ee95dac32b158c50ca7fccd8a);
#
#
#
#         marker_c37d188279088874fdf13ab866875cb6.bindPopup(popup_6ae797a01a4db35771070e8d16ee6885)
#         ;
#
#
#
#
#             var marker_9f8525b0c019cc5a2434ae8539e88ce9 = L.marker(
#                 [51.4604986, -0.1685329],
#                 {}
#             ).addTo(map_09ebecf1246a2f78653d8cee0d248d69);
#
#
#         var popup_668c3cfbbdfe03ee2d9b63f49c27aebd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43e32b524eabd2f1018cd5cc0033116c = $(`&lt;div id=&quot;html_43e32b524eabd2f1018cd5cc0033116c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Battersea (Q1), 119 Battersea Rise, London SW11 1HW&lt;/div&gt;`)[0];
#                 popup_668c3cfbbdfe03ee2d9b63f49c27aebd.setContent(html_43e32b524eabd2f1018cd5cc0033116c);
#
#
#
#         marker_9f8525b0c019cc5a2434ae8539e88ce9.bindPopup(popup_668c3cfbbdfe03ee2d9b63f49c27aebd)
#         ;
#
#
#
#
#             var marker_5d1865460b7edbaee0571f569df18c36 = L.marker(
#                 [51.4082101, -0.0360337],
#                 {}
#             ).addTo(map_09ebecf1246a2f78653d8cee0d248d69);
#
#
#         var popup_f3430a6b984aa965e7edf370cf7da117 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89c2d46df31929d698c30b08c4552aa2 = $(`&lt;div id=&quot;html_89c2d46df31929d698c30b08c4552aa2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beckenham (M4), 12 Beckenham Road, Beckenham Kent BR3 4LR&lt;/div&gt;`)[0];
#                 popup_f3430a6b984aa965e7edf370cf7da117.setContent(html_89c2d46df31929d698c30b08c4552aa2);
#
#
#
#         marker_5d1865460b7edbaee0571f569df18c36.bindPopup(popup_f3430a6b984aa965e7edf370cf7da117)
#         ;
#
#
#
#
#             var marker_a84831c38eeb4046c99abb4699873dda = L.marker(
#                 [51.4589721, -0.1026163],
#                 {}
#             ).addTo(map_09ebecf1246a2f78653d8cee0d248d69);
#
#
#         var popup_ff31b8174c3145229f03a04e9feace25 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43da73d175f39109080e97615bfa77bb = $(`&lt;div id=&quot;html_43da73d175f39109080e97615bfa77bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brixton (Q2), Unit 25 Bessemer Park, 250 Milkwood Road, London SE24 0HG&lt;/div&gt;`)[0];
#                 popup_ff31b8174c3145229f03a04e9feace25.setContent(html_43da73d175f39109080e97615bfa77bb);
#
#
#
#         marker_a84831c38eeb4046c99abb4699873dda.bindPopup(popup_ff31b8174c3145229f03a04e9feace25)
#         ;
#
#
#
#
#             var marker_146cedca8140f4656b55e6b19f0fb6d5 = L.marker(
#                 [51.3893951, 0.0372213],
#                 {}
#             ).addTo(map_09ebecf1246a2f78653d8cee0d248d69);
#
#
#         var popup_cc700502b505124ee525435bae5f01e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8050b339248b20d559aa178c2262852 = $(`&lt;div id=&quot;html_b8050b339248b20d559aa178c2262852&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bromley (M1), Crown Lane, Bromley Kent BR2 9PW&lt;/div&gt;`)[0];
#                 popup_cc700502b505124ee525435bae5f01e3.setContent(html_b8050b339248b20d559aa178c2262852);
#
#
#
#         marker_146cedca8140f46

# %% [markdown]
# ------------

# %% [markdown]
# ### Read LAS and LFB Calls Data

# %%
# Read the LAS Calls DATA

# LAS Calls
file_path = '../data/LAS/DataApril2023/LAS-From 2018 to 2023.xlsx'
IncidentsLSOA = pd.read_excel(file_path, engine='openpyxl', sheet_name='IncidentsLSOA')
# LFB Calls
london = pd.read_csv('../data/LFB/LFB Incident data 2020 to 2023.csv')

# Read the .xls file
LSOA_country_of_birth = pd.read_excel('../data/LSOA-Census-Demographics/Country of birth.xlsx',
                                      engine='openpyxl', sheet_name='2021')
# Latitude and Longitude of Borough Data
lsoa_location = pd.read_csv("../data/LSOA-Census-Demographics/lsoa_latlong.csv")

# %% [markdown]
# **Filter it for the last 2 years**

# %% [markdown]
# **LAS**

# %%
# Create a mask of boolean values indicating whether each date is within the specified range
mask_two = IncidentsLSOA['year'] >= 2021

# Apply the mask to the DataFrame to get a new DataFrame with dates within the specified range
IncidentsLSOA = IncidentsLSOA.loc[mask_two].reset_index(drop=True)

# merge with inner
merged_df = IncidentsLSOA.merge(LSOA_country_of_birth, how='inner', left_on='LSOA11CD', right_on='LSOA code')
# drop the 'LSOA code' column
merged_df = merged_df.drop(columns=['LSOA code'])

# merge with inner
merged_df = merged_df.merge(lsoa_location, how='inner', left_on='LSOA11CD', right_on='lsoa11cd')
# drop the 'LSOA code' column
merged_df = merged_df.drop(columns=['lsoa11cd'])

las_by_borough_last_2_years = merged_df.groupby(["local authority name"])["total_incidents"].\
                                                                        sum().sort_values(ascending=False)

# Convert your series to a DataFrame
las_df = las_by_borough_last_2_years.reset_index()
las_df.columns = ['name', 'total_incidents']
las_df['name'] = las_df['name'].str.title()

# %% [markdown]
# **LFB**

# %%
london['DateOfCall'] = pd.to_datetime(london['DateOfCall']).dt.date

start_date = pd.Timestamp("2021-01-01").date()
end_date = pd.Timestamp("2023-01-31").date()

# Filter dataframe based on date range
london_filtered = london[(london['DateOfCall'] >= start_date) & (london['DateOfCall'] <= end_date)]

lfb_by_borough = london_filtered.groupby(['ProperCase'])["NumCalls"].sum().sort_values(ascending=False)

# Convert series to dataframe
lfb_by_borough_df = lfb_by_borough.reset_index()
lfb_by_borough_df.columns = ['name', 'total_incidents']
lfb_by_borough_df['name'] = lfb_by_borough_df['name'].str.title()

# %% [markdown]
# ## Choropleth Map: Total Incidents per boroughs vs LAS Locations

# %%
# Create a map centered around London with cartodbpositron tiles
m = folium.Map(location=[51.5074, -0.1278], zoom_start=10, tiles='cartodbpositron')

# Add a marker for each location in the DataFrame
for index, row in las_data.iterrows():
    folium.Marker(location=[row['Latitude'], row['Longitude']], 
                  popup=f"{row['Station/code']}, {row['Address']}"
                 ).add_to(m)

# Convert the borough boundaries to json format
geo_json_data = boroughs_gdf.to_json()

# Create the choropleth map. Key_on refers to the borough name in the GeoJSON file
folium.Choropleth(
    geo_data=geo_json_data,
    name='choropleth',
    data=las_df,
    columns=['name', 'total_incidents'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    line_color='black',
    legend_name='Total Incidents'
).add_to(m)

folium.LayerControl().add_to(m)

m.save('choropleth_map_v1.html')

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9839d460d183acacbee92bb5ed27399 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9839d460d183acacbee92bb5ed27399&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9839d460d183acacbee92bb5ed27399 = L.map(
#                 &quot;map_d9839d460d183acacbee92bb5ed27399&quot;,
#                 {
#                     center: [51.5074, -0.1278],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02c2f3e7c171150ba562ef0fb475943c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d9839d460d183acacbee92bb5ed27399);
#
#
#             var marker_8be9cac22e12b9e491595bd07755b08d = L.marker(
#                 [51.4608009, 0.153816],
#                 {}
#             ).addTo(map_d9839d460d183acacbee92bb5ed27399);
#
#
#         var popup_136ee5ef03411379bb3b4cbc1966f3c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8c3fba1482a7829c69919e91a63e068 = $(`&lt;div id=&quot;html_c8c3fba1482a7829c69919e91a63e068&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barnehurst (L1), 164 Erith Road, Bexleyheath, Kent, DA7 6BZ&lt;/div&gt;`)[0];
#                 popup_136ee5ef03411379bb3b4cbc1966f3c6.setContent(html_c8c3fba1482a7829c69919e91a63e068);
#
#
#
#         marker_8be9cac22e12b9e491595bd07755b08d.bindPopup(popup_136ee5ef03411379bb3b4cbc1966f3c6)
#         ;
#
#
#
#
#             var marker_e4d58493586c01033036b11ba65a1fe7 = L.marker(
#                 [51.4604986, -0.1685329],
#                 {}
#             ).addTo(map_d9839d460d183acacbee92bb5ed27399);
#
#
#         var popup_4450da4fc8abda8e76fed71943b526f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc010e2726e3e482e05ee4ade6358e39 = $(`&lt;div id=&quot;html_dc010e2726e3e482e05ee4ade6358e39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Battersea (Q1), 119 Battersea Rise, London SW11 1HW&lt;/div&gt;`)[0];
#                 popup_4450da4fc8abda8e76fed71943b526f2.setContent(html_dc010e2726e3e482e05ee4ade6358e39);
#
#
#
#         marker_e4d58493586c01033036b11ba65a1fe7.bindPopup(popup_4450da4fc8abda8e76fed71943b526f2)
#         ;
#
#
#
#
#             var marker_f253e524e270177faa0a74c291a15ffc = L.marker(
#                 [51.4082101, -0.0360337],
#                 {}
#             ).addTo(map_d9839d460d183acacbee92bb5ed27399);
#
#
#         var popup_31cc40d838a24c621472868a6aee0a60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb8ad17c7dd0815414c98a8b93904876 = $(`&lt;div id=&quot;html_fb8ad17c7dd0815414c98a8b93904876&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beckenham (M4), 12 Beckenham Road, Beckenham Kent BR3 4LR&lt;/div&gt;`)[0];
#                 popup_31cc40d838a24c621472868a6aee0a60.setContent(html_fb8ad17c7dd0815414c98a8b93904876);
#
#
#
#         marker_f253e524e270177faa0a74c291a15ffc.bindPopup(popup_31cc40d838a24c621472868a6aee0a60)
#         ;
#
#
#
#
#             var marker_90466426db759f1cf7fb9465836c831e = L.marker(
#                 [51.4589721, -0.1026163],
#                 {}
#             ).addTo(map_d9839d460d183acacbee92bb5ed27399);
#
#
#         var popup_bad621e47c3f366cc7bce8649ab66681 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f715f2fb3f5ae909876f2be354eda435 = $(`&lt;div id=&quot;html_f715f2fb3f5ae909876f2be354eda435&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brixton (Q2), Unit 25 Bessemer Park, 250 Milkwood Road, London SE24 0HG&lt;/div&gt;`)[0];
#                 popup_bad621e47c3f366cc7bce8649ab66681.setContent(html_f715f2fb3f5ae909876f2be354eda435);
#
#
#
#         marker_90466426db759f1cf7fb9465836c831e.bindPopup(popup_bad621e47c3f366cc7bce8649ab66681)
#         ;
#
#
#
#
#             var marker_1609d3ece5f2780c56aaf4d042b8af8e = L.marker(
#                 [51.3893951, 0.0372213],
#                 {}
#             ).addTo(map_d9839d460d183acacbee92bb5ed27399);
#
#
#         var popup_823aff4dacfe532f9e6ddcece8a00ab1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1153c26506be541d8d6486b79335bc3e = $(`&lt;div id=&quot;html_1153c26506be541d8d6486b79335bc3e&

# %% [markdown]
# ## Choropleth Map: Total Incidents per boroughs vs LFB Locations

# %%
# Create a map centered around London with cartodbpositron tiles
m = folium.Map(location=[51.5074, -0.1278], zoom_start=10, tiles='cartodbpositron')

# Add a marker for each location in the DataFrame
for index, row in lfb_data.iterrows():
    folium.Marker(location=[row['Latitude'], row['Longitude']], 
                  popup=f"{row['Station/code']}, {row['Address']}"
                 ).add_to(m)

# Convert the borough boundaries to json format
geo_json_data = boroughs_gdf.to_json()

# Create the choropleth map. Key_on refers to the borough name in the GeoJSON file
folium.Choropleth(
    geo_data=geo_json_data,
    name='choropleth',
    data=lfb_by_borough_df,
    columns=['name', 'total_incidents'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    line_color='blue',
    legend_name='Total Incidents'
).add_to(m)

folium.LayerControl().add_to(m)

m.save('lfb_choropleth_map_v1.html')

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b91ab7bfe27fa0776be78dfda0fcca6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b91ab7bfe27fa0776be78dfda0fcca6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b91ab7bfe27fa0776be78dfda0fcca6 = L.map(
#                 &quot;map_3b91ab7bfe27fa0776be78dfda0fcca6&quot;,
#                 {
#                     center: [51.5074, -0.1278],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2edbf349e566f53e5013fad30be597f0 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b91ab7bfe27fa0776be78dfda0fcca6);
#
#
#             var marker_3cc136eb2872dcdc3d2087df878890aa = L.marker(
#                 [51.5294843, 0.0902007],
#                 {}
#             ).addTo(map_3b91ab7bfe27fa0776be78dfda0fcca6);
#
#
#         var popup_2cd474d7b84102d0d29cd4ad5e1ff0b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_103594c435b6e2e50e83f628d249f31a = $(`&lt;div id=&quot;html_103594c435b6e2e50e83f628d249f31a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Barking, Alfred&#x27;s Way, IG11 0BB&lt;/div&gt;`)[0];
#                 popup_2cd474d7b84102d0d29cd4ad5e1ff0b7.setContent(html_103594c435b6e2e50e83f628d249f31a);
#
#
#
#         marker_3cc136eb2872dcdc3d2087df878890aa.bindPopup(popup_2cd474d7b84102d0d29cd4ad5e1ff0b7)
#         ;
#
#
#
#
#             var marker_6b15128384c53479bd3e1f6c99f6d1eb = L.marker(
#                 [51.5593514, 0.1569352],
#                 {}
#             ).addTo(map_3b91ab7bfe27fa0776be78dfda0fcca6);
#
#
#         var popup_97297d7012302e856735b0a098e1b583 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd05c855dc279ef8d8dbe1afee2d9399 = $(`&lt;div id=&quot;html_bd05c855dc279ef8d8dbe1afee2d9399&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dagenham, 70 Rainham Road North, Dagenham, RM10 7ES&lt;/div&gt;`)[0];
#                 popup_97297d7012302e856735b0a098e1b583.setContent(html_bd05c855dc279ef8d8dbe1afee2d9399);
#
#
#
#         marker_6b15128384c53479bd3e1f6c99f6d1eb.bindPopup(popup_97297d7012302e856735b0a098e1b583)
#         ;
#
#
#
#
#             var marker_007bea4266c39c1ba65ce6f734849500 = L.marker(
#                 [51.5100529, -0.0902268],
#                 {}
#             ).addTo(map_3b91ab7bfe27fa0776be78dfda0fcca6);
#
#
#         var popup_834f9dc9fc0e604110e5fa50355bbc25 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f8926bfe5d0dd96e3128708a3f3de1b = $(`&lt;div id=&quot;html_7f8926bfe5d0dd96e3128708a3f3de1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dowgate, 94-95 Upper Thames Street, EC4R 3UE&lt;/div&gt;`)[0];
#                 popup_834f9dc9fc0e604110e5fa50355bbc25.setContent(html_7f8926bfe5d0dd96e3128708a3f3de1b);
#
#
#
#         marker_007bea4266c39c1ba65ce6f734849500.bindPopup(popup_834f9dc9fc0e604110e5fa50355bbc25)
#         ;
#
#
#
#
#             var marker_f0529d2295a5e1b26b506e5c1a16d79f = L.marker(
#                 [51.5264428, -0.0855632],
#                 {}
#             ).addTo(map_3b91ab7bfe27fa0776be78dfda0fcca6);
#
#
#         var popup_d78bc18b354bee70a659c2f550980d54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_633f176fd7822d433c59027dc927e54a = $(`&lt;div id=&quot;html_633f176fd7822d433c59027dc927e54a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shoreditch, 235 Old Street, EC1V 9EY&lt;/div&gt;`)[0];
#                 popup_d78bc18b354bee70a659c2f550980d54.setContent(html_633f176fd7822d433c59027dc927e54a);
#
#
#
#         marker_f0529d2295a5e1b26b506e5c1a16d79f.bindPopup(popup_d78bc18b354bee70a659c2f550980d54)
#         ;
#
#
#
#
#             var marker_3f915cf9e79d3352f02a2dd1e7f11fdc = L.marker(
#                 [51.5624308, -0.0769413],
#                 {}
#             ).addTo(map_3b91ab7bfe27fa0776be78dfda0fcca6);
#
#
#         var popup_b620302714d575a5d75825c971615de6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1b678001b4b1feb11df5106effee274 = $(`&lt;div id=&quot;html_f1b678001b4b1feb11df5106effee274&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stoke Newing
